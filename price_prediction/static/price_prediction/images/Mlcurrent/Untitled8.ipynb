# %%
import pandas as pd

df = pd.read_csv('linear_mid.csv')
df.head()
# Out:
#             Commodity        Date   Average   day  month    year  Season_Fall  \
# 0  Tomato Big(Nepali)  2013-06-16  3.624341  16.0    6.0  2013.0        False
# 1        Potato White  2013-06-16  2.740840  16.0    6.0  2013.0        False
# 2  Onion Dry (Indian)  2013-06-16  3.367296  16.0    6.0  2013.0        False
# 3       Carrot(Local)  2013-06-16  3.481240  16.0    6.0  2013.0        False
# 4             Lettuce  2013-06-16  4.051785  16.0    6.0  2013.0        False
#
#    Season_Spring  Season_Summer  Season_Winter  Apple(Jholey)  Banana  \
# 0          False           True          False          False   False
# 1          False           True          False          False   False
# 2          False           True          False          False   False
# 3          False           True          False          False   False
# 4          False           True          False          False   False
#
#    Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  Lettuce  \
# 0          False            False              False    False
# 1          False            False              False    False
# 2          False            False              False    False
# 3           True            False              False    False
# 4          False            False              False     True
#
#    Onion Dry (Indian)  Potato White  Tomato Big(Nepali)
# 0               False         False                True
# 1               False          True               False
# 2                True         False               False
# 3               False         False               False
# 4               False         False               False

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Commodity_LabelEncoded'] = label_encoder.fit_transform(df['Commodity'])

# %%
df.head()
# Out:
#             Commodity        Date   Average   day  month    year  Season_Fall  \
# 0  Tomato Big(Nepali)  2013-06-16  3.624341  16.0    6.0  2013.0        False
# 1        Potato White  2013-06-16  2.740840  16.0    6.0  2013.0        False
# 2  Onion Dry (Indian)  2013-06-16  3.367296  16.0    6.0  2013.0        False
# 3       Carrot(Local)  2013-06-16  3.481240  16.0    6.0  2013.0        False
# 4             Lettuce  2013-06-16  4.051785  16.0    6.0  2013.0        False
#
#    Season_Spring  Season_Summer  Season_Winter  Apple(Jholey)  Banana  \
# 0          False           True          False          False   False
# 1          False           True          False          False   False
# 2          False           True          False          False   False
# 3          False           True          False          False   False
# 4          False           True          False          False   False
#
#    Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  Lettuce  \
# 0          False            False              False    False
# 1          False            False              False    False
# 2          False            False              False    False
# 3           True            False              False    False
# 4          False            False              False     True
#
#    Onion Dry (Indian)  Potato White  Tomato Big(Nepali)  \
# 0               False         False                True
# 1               False          True               False
# 2                True         False               False
# 3               False         False               False
# 4               False         False               False
#
#    Commodity_LabelEncoded
# 0                       8
# 1                       7
# 2                       6
# 3                       2
# 4                       5

# %%
df.drop(['Date'], axis=1, inplace=True)

# %%
correlation_matrix = df.corr()

target_variable = 'Average' 
correlation_with_target = correlation_matrix[target_variable].sort_values(ascending=False)
print(correlation_with_target)
# Out:
# Average                   1.000000
# Garlic Dry Nepali         0.427517
# Apple(Jholey)             0.339389
# year                      0.226546
# month                     0.163335
# Banana                    0.162712
# Season_Fall               0.158095
# Lettuce                   0.053339
# Season_Summer             0.025175
# day                       0.004460
# Carrot(Local)            -0.037863
# Season_Winter            -0.058298
# Cucumber(Local)          -0.094323
# Season_Spring            -0.128747
# Tomato Big(Nepali)       -0.146435
# Onion Dry (Indian)       -0.250282
# Potato White             -0.453843
# Commodity_LabelEncoded   -0.491066
# Name: Average, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil import parser
import re
import matplotlib.patches as patches
import matplotlib

# %%
data = pd.read_csv("Tarkari.csv", low_memory=False)
data.head()
# Out:
#              Commodity       Date Unit Minimum Maximum Average
# 0   Tomato Big(Nepali)  6/16/2013   Kg      35      40    37.5
# 1  Tomato Small(Local)  6/16/2013   Kg      26      32      29
# 2           Potato Red  6/16/2013   Kg      20      21    20.5
# 3         Potato White  6/16/2013   Kg      15      16    15.5
# 4   Onion Dry (Indian)  6/16/2013   Kg      28      30      29

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
pattern = r"^Rs\s+"
data["Minimum"] = pd.to_numeric(data["Minimum"].apply(lambda x: x if not str(x).startswith("Rs") else re.sub(pattern,"",str(x))))
data["Maximum"] = pd.to_numeric(data["Maximum"].apply(lambda x: x if not str(x).startswith("Rs") else re.sub(r"^Rs\s+", "",str(x))))
data["Average"] = pd.to_numeric(data["Average"].apply(lambda x: x if not str(x).startswith("Rs") else re.sub(r"^Rs\s+", "", str(x))))

# %%
selected_commodities = ['Onion Dry (Indian)', 'Tomato Big(Nepali)', 'Potato White', 'Carrot(Local)', 'Apple(Jholey)', 'Banana', 'Cucumber(Local)', 'Garlic Dry Nepali', 'Lettuce']
selected_data = data[data['Commodity'].isin(selected_commodities)].copy()

# %%
selected_data.head()
# Out:
#              Commodity       Date Unit  Minimum  Maximum  Average
# 0   Tomato Big(Nepali) 2013-06-16   Kg     35.0     40.0     37.5
# 3         Potato White 2013-06-16   Kg     15.0     16.0     15.5
# 4   Onion Dry (Indian) 2013-06-16   Kg     28.0     30.0     29.0
# 5        Carrot(Local) 2013-06-16   Kg     30.0     35.0     32.5
# 40             Lettuce 2013-06-16   Kg     55.0     60.0     57.5

# %%
selected_data.loc[:, 'Season'] = selected_data['Date'].dt.month.map({1: 'Winter', 2: 'Winter', 3: 'Spring', 4: 'Spring', 5: 'Spring', 6: 'Summer', 7: 'Summer', 8: 'Summer', 9: 'Fall', 10: 'Fall', 11: 'Fall', 12: 'Winter'})

# %%
selected_data.head()

df1 = selected_data.copy()

# %%
import pandas as pd
import numpy as np


encoded_season = pd.get_dummies(df1['Season'])

df_encoded = pd.concat([df1, encoded_season], axis=1)

correlation_values = {}
for season in encoded_season.columns:
    correlation = np.corrcoef(df_encoded['Average'], df_encoded[season])[0, 1]
    correlation_values[season] = correlation

# Display the correlation values
print("Correlation of 'Average' with each 'Season':")
print(correlation_values)
# Out:
# Correlation of 'Average' with each 'Season':
# {'Fall': 0.12960584438185, 'Spring': -0.09445990751014083, 'Summer': -0.0016966679026269014, 'Winter': -0.035876653332755776}

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Commodity_LabelEncoded'] = label_encoder.fit_transform(df['Commodity'])

# %%
df1.head()
# Out:
#              Commodity       Date Unit  Minimum  Maximum  Average  Season
# 0   Tomato Big(Nepali) 2013-06-16   Kg     35.0     40.0     37.5  Summer
# 3         Potato White 2013-06-16   Kg     15.0     16.0     15.5  Summer
# 4   Onion Dry (Indian) 2013-06-16   Kg     28.0     30.0     29.0  Summer
# 5        Carrot(Local) 2013-06-16   Kg     30.0     35.0     32.5  Summer
# 40             Lettuce 2013-06-16   Kg     55.0     60.0     57.5  Summer

# %%
df = pd.read_csv("lagadded_outrem.csv", low_memory=False)
