# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv("filtered_features.csv", low_memory=False)
df.head()
# Out:
#             Commodity        Date Unit  Minimum  Maximum  Average  day  month  \
# 0  Tomato Big(Nepali)  2019-01-01   Kg     45.0     50.0     47.5    1      1
# 1        Potato White  2019-01-01   Kg     20.0     25.0     22.5    1      1
# 2  Onion Dry (Indian)  2019-01-01   Kg     26.0     28.0     27.0    1      1
# 3       Carrot(Local)  2019-01-01   Kg     55.0     60.0     57.5    1      1
# 4             Lettuce  2019-01-01   Kg     90.0    100.0     95.0    1      1
#
#    year  Season_Fall  Season_Spring  Season_Summer  Season_Winter
# 0  2019        False          False          False           True
# 1  2019        False          False          False           True
# 2  2019        False          False          False           True
# 3  2019        False          False          False           True
# 4  2019        False          False          False           True

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Date = df.Date.astype(str)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#             Commodity       Date Unit  Minimum  Maximum  Average  day  month  \
# 0  Tomato Big(Nepali) 2019-01-01   Kg     45.0     50.0     47.5    1      1
# 1        Potato White 2019-01-01   Kg     20.0     25.0     22.5    1      1
# 2  Onion Dry (Indian) 2019-01-01   Kg     26.0     28.0     27.0    1      1
# 3       Carrot(Local) 2019-01-01   Kg     55.0     60.0     57.5    1      1
# 4             Lettuce 2019-01-01   Kg     90.0    100.0     95.0    1      1
#
#    year  Season_Fall  Season_Spring  Season_Summer  Season_Winter
# 0  2019        False          False          False           True
# 1  2019        False          False          False           True
# 2  2019        False          False          False           True
# 3  2019        False          False          False           True
# 4  2019        False          False          False           True

# %%
df.dtypes
# Out:
# Commodity                object
# Date             datetime64[ns]
# Unit                     object
# Minimum                 float64
# Maximum                 float64
# Average                 float64
# day                       int64
# month                     int64
# year                      int64
# Season_Fall                bool
# Season_Spring              bool
# Season_Summer              bool
# Season_Winter              bool
# dtype: object

# %%
df.drop(['Maximum', 'Minimum'], axis=1, inplace=True)

# %%
df.drop(['month','day'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#             Commodity       Date Unit  Average  year  Season_Fall  \
# 0  Tomato Big(Nepali) 2019-01-01   Kg     47.5  2019        False
# 1        Potato White 2019-01-01   Kg     22.5  2019        False
# 2  Onion Dry (Indian) 2019-01-01   Kg     27.0  2019        False
# 3       Carrot(Local) 2019-01-01   Kg     57.5  2019        False
# 4             Lettuce 2019-01-01   Kg     95.0  2019        False
#
#    Season_Spring  Season_Summer  Season_Winter
# 0          False          False           True
# 1          False          False           True
# 2          False          False           True
# 3          False          False           True
# 4          False          False           True

# %%
df.drop('Date', axis = 1, inplace = True)

# %%
df.head()
# Out:
#             Commodity Unit  Average  year  Season_Fall  Season_Spring  \
# 0  Tomato Big(Nepali)   Kg     47.5  2019        False          False
# 1        Potato White   Kg     22.5  2019        False          False
# 2  Onion Dry (Indian)   Kg     27.0  2019        False          False
# 3       Carrot(Local)   Kg     57.5  2019        False          False
# 4             Lettuce   Kg     95.0  2019        False          False
#
#    Season_Summer  Season_Winter
# 0          False           True
# 1          False           True
# 2          False           True
# 3          False           True
# 4          False           True

# %%
df
# Out:
#                 Commodity Unit  Average  year  Season_Fall  Season_Spring  \
# 0      Tomato Big(Nepali)   Kg    47.50  2019        False          False
# 1            Potato White   Kg    22.50  2019        False          False
# 2      Onion Dry (Indian)   Kg    27.00  2019        False          False
# 3           Carrot(Local)   Kg    57.50  2019        False          False
# 4                 Lettuce   Kg    95.00  2019        False          False
# ...                   ...  ...      ...   ...          ...            ...
# 13494     Cucumber(Local)   KG    65.00  2023         True          False
# 13495   Garlic Dry Nepali   KG   256.67  2023         True          False
# 13496             Lettuce   KG    96.67  2023         True          False
# 13497  Onion Dry (Indian)   KG    71.60  2023         True          False
# 13498        Potato White   KG    47.00  2023         True          False
#
#        Season_Summer  Season_Winter
# 0              False           True
# ...

# %%
import pandas as pd
import seaborn as sns
from scipy import stats

z_scores = stats.zscore(df['Average'])

# Visualize the distribution of Z-scores
sns.histplot(z_scores, kde=True)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
z_scores
# Out:
# 0       -0.728240
# 1       -1.129760
# 2       -1.057486
# 3       -0.567632
# 4        0.034647
#            ...
# 13494   -0.447176
# 13495    2.631195
# 13496    0.061469
# 13497   -0.341175
# 13498   -0.736271
# Name: Average, Length: 13499, dtype: float64

# %%
import pandas as pd
from scipy import stats

column_name = 'Average'

z_scores = stats.zscore(df['Average'])

threshold = 3

df_no_outliers = df[(z_scores < threshold) & (z_scores > -threshold)]

# %%
df_no_outliers
# Out:
#                 Commodity Unit  Average  year  Season_Fall  Season_Spring  \
# 0      Tomato Big(Nepali)   Kg    47.50  2019        False          False
# 1            Potato White   Kg    22.50  2019        False          False
# 2      Onion Dry (Indian)   Kg    27.00  2019        False          False
# 3           Carrot(Local)   Kg    57.50  2019        False          False
# 4                 Lettuce   Kg    95.00  2019        False          False
# ...                   ...  ...      ...   ...          ...            ...
# 13494     Cucumber(Local)   KG    65.00  2023         True          False
# 13495   Garlic Dry Nepali   KG   256.67  2023         True          False
# 13496             Lettuce   KG    96.67  2023         True          False
# 13497  Onion Dry (Indian)   KG    71.60  2023         True          False
# 13498        Potato White   KG    47.00  2023         True          False
#
#        Season_Summer  Season_Winter
# 0              False           True
# ...

# %%
df=df_no_outliers.copy()

# %%
df['year'] = df['year'].astype(float)

# %%
df.dtypes
# Out:
# Commodity         object
# Unit              object
# Average          float64
# year             float64
# Season_Fall         bool
# Season_Spring       bool
# Season_Summer       bool
# Season_Winter       bool
# dtype: object

# %%
df.drop('Unit', axis=1, inplace=True)

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10,5))
plt.title('Skewness in Price', fontsize = 15)
sns.set(font_scale = 1)
sns.histplot(df['Average'], kde = True)
plt.show()
display('-----------------------------------')
display(df['Average'].skew())
# Out:
# '-----------------------------------'
# 1.03198695403106

# %%
df['Average'] = np.log(df.Average + 1e-10)

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10,5))
plt.title('Skewness in Price', fontsize = 15)
sns.set(font_scale = 1)
sns.histplot(df['Average'], kde = True)
plt.show()
display('-----------------------------------')
display(df['Average'].skew())
# Out:
# '-----------------------------------'
# -0.15924036504573477

# %%
df4 = pd.get_dummies(df['Commodity'])

# %%
df.head()
# Out:
#             Commodity   Average    year  Season_Fall  Season_Spring  \
# 0  Tomato Big(Nepali)  3.860730  2019.0        False          False
# 1        Potato White  3.113515  2019.0        False          False
# 2  Onion Dry (Indian)  3.295837  2019.0        False          False
# 3       Carrot(Local)  4.051785  2019.0        False          False
# 4             Lettuce  4.553877  2019.0        False          False
#
#    Season_Summer  Season_Winter
# 0          False           True
# 1          False           True
# 2          False           True
# 3          False           True
# 4          False           True

# %%
df4.head()
# Out:
#    Apple(Jholey)  Banana  Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  \
# 0          False   False          False            False              False
# 1          False   False          False            False              False
# 2          False   False          False            False              False
# 3          False   False           True            False              False
# 4          False   False          False            False              False
#
#    Lettuce  Onion Dry (Indian)  Potato White  Tomato Big(Nepali)
# 0    False               False         False                True
# 1    False               False          True               False
# 2    False                True         False               False
# 3    False               False         False               False
# 4     True               False         False               False

# %%
df5 = df.copy()
df = pd.concat([df, df4], axis = 1)

# %%
df.head()
# Out:
#             Commodity   Average    year  Season_Fall  Season_Spring  \
# 0  Tomato Big(Nepali)  3.860730  2019.0        False          False
# 1        Potato White  3.113515  2019.0        False          False
# 2  Onion Dry (Indian)  3.295837  2019.0        False          False
# 3       Carrot(Local)  4.051785  2019.0        False          False
# 4             Lettuce  4.553877  2019.0        False          False
#
#    Season_Summer  Season_Winter  Apple(Jholey)  Banana  Carrot(Local)  \
# 0          False           True          False   False          False
# 1          False           True          False   False          False
# 2          False           True          False   False          False
# 3          False           True          False   False           True
# 4          False           True          False   False          False
#
#    Cucumber(Local)  Garlic Dry Nepali  Lettuce  Onion Dry (Indian)  \
# ...

# %%
df.drop('Commodity', axis = 1, inplace = True)

# %%
df.head()
# Out:
#     Average    year  Season_Fall  Season_Spring  Season_Summer  Season_Winter  \
# 0  3.860730  2019.0        False          False          False           True
# 1  3.113515  2019.0        False          False          False           True
# 2  3.295837  2019.0        False          False          False           True
# 3  4.051785  2019.0        False          False          False           True
# 4  4.553877  2019.0        False          False          False           True
#
#    Apple(Jholey)  Banana  Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  \
# 0          False   False          False            False              False
# 1          False   False          False            False              False
# 2          False   False          False            False              False
# 3          False   False           True            False              False
# 4          False   False          False            False              False
#
# ...

# %%
df = df.dropna()

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Average', axis = 1),
 df.Average, test_size = 0.1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_pred, y_test)
accuracy = model.score(x_test, y_test) * 100

print("MACHINE LEARNING MODEL'S MEAN SQUARE ERROR\t:\t", mse)
print("MACHINE LEARNING MODEL'S ACCURACY\t\t:\t", accuracy, '%')
# Out:
# MACHINE LEARNING MODEL'S MEAN SQUARE ERROR	:	 0.13695490532169358
# MACHINE LEARNING MODEL'S ACCURACY		:	 63.67826728048893 %

# %%
df1 = pd.read_csv("filtered_features.csv", low_memory=False)

# %%
df1.dtypes
# Out:
# Commodity         object
# Date              object
# Unit              object
# Minimum          float64
# Maximum          float64
# Average          float64
# day                int64
# month              int64
# year               int64
# Season_Fall         bool
# Season_Spring       bool
# Season_Summer       bool
# Season_Winter       bool
# dtype: object

# %%
df1.drop('Date', axis = 1, inplace = True)

# %%
df1['year'] = df1['year'].astype(float)
df1['month'] = df1['month'].astype(float)
df1['day'] = df1['day'].astype(float)

# %%
df1.dtypes
# Out:
# Commodity         object
# Unit              object
# Minimum          float64
# Maximum          float64
# Average          float64
# day              float64
# month            float64
# year             float64
# Season_Fall         bool
# Season_Spring       bool
# Season_Summer       bool
# Season_Winter       bool
# dtype: object

# %%
df1.drop('Unit', axis = 1, inplace = True)

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10,5))
plt.title('Skewness in Price', fontsize = 15)
sns.set(font_scale = 1)
sns.histplot(df1['Average'], kde = True)
plt.show()
display('-----------------------------------')
display(df1['Average'].skew())
# Out:
# '-----------------------------------'
# 2.399807839384547

# %%
df1['Average'] = np.log(df1.Average + 1e-10)

# %%
df1.head()
# Out:
#             Commodity  Minimum  Maximum   Average  day  month    year  \
# 0  Tomato Big(Nepali)     45.0     50.0  3.860730  1.0    1.0  2019.0
# 1        Potato White     20.0     25.0  3.113515  1.0    1.0  2019.0
# 2  Onion Dry (Indian)     26.0     28.0  3.295837  1.0    1.0  2019.0
# 3       Carrot(Local)     55.0     60.0  4.051785  1.0    1.0  2019.0
# 4             Lettuce     90.0    100.0  4.553877  1.0    1.0  2019.0
#
#    Season_Fall  Season_Spring  Season_Summer  Season_Winter
# 0        False          False          False           True
# 1        False          False          False           True
# 2        False          False          False           True
# 3        False          False          False           True
# 4        False          False          False           True

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10,5))
plt.title('Skewness in Price', fontsize = 15)
sns.set(font_scale = 1)
sns.histplot(df1['Minimum'], kde = True)
plt.show()
display('-----------------------------------')
display(df1['Minimum'].skew())
# Out:
# '-----------------------------------'
# 2.3128108176127506

# %%
df1['Minimum'] = np.log(df1.Minimum + 1e-10)
df1['Maximum'] = np.log(df1.Maximum + 1e-10)

# %%
df1.head()
# Out:
#             Commodity   Minimum   Maximum   Average  day  month    year  \
# 0  Tomato Big(Nepali)  3.806662  3.912023  3.860730  1.0    1.0  2019.0
# 1        Potato White  2.995732  3.218876  3.113515  1.0    1.0  2019.0
# 2  Onion Dry (Indian)  3.258097  3.332205  3.295837  1.0    1.0  2019.0
# 3       Carrot(Local)  4.007333  4.094345  4.051785  1.0    1.0  2019.0
# 4             Lettuce  4.499810  4.605170  4.553877  1.0    1.0  2019.0
#
#    Season_Fall  Season_Spring  Season_Summer  Season_Winter
# 0        False          False          False           True
# 1        False          False          False           True
# 2        False          False          False           True
# 3        False          False          False           True
# 4        False          False          False           True

# %%
df4 = pd.get_dummies(df1['Commodity'])

# %%
df4.head()
# Out:
#    Apple(Jholey)  Banana  Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  \
# 0          False   False          False            False              False
# 1          False   False          False            False              False
# 2          False   False          False            False              False
# 3          False   False           True            False              False
# 4          False   False          False            False              False
#
#    Lettuce  Onion Dry (Indian)  Potato White  Tomato Big(Nepali)
# 0    False               False         False                True
# 1    False               False          True               False
# 2    False                True         False               False
# 3    False               False         False               False
# 4     True               False         False               False

# %%
df5 = df1.copy()
df1 = pd.concat([df1, df4], axis = 1)

# %%
df1.head()
# Out:
#             Commodity   Minimum   Maximum   Average  day  month    year  \
# 0  Tomato Big(Nepali)  3.806662  3.912023  3.860730  1.0    1.0  2019.0
# 1        Potato White  2.995732  3.218876  3.113515  1.0    1.0  2019.0
# 2  Onion Dry (Indian)  3.258097  3.332205  3.295837  1.0    1.0  2019.0
# 3       Carrot(Local)  4.007333  4.094345  4.051785  1.0    1.0  2019.0
# 4             Lettuce  4.499810  4.605170  4.553877  1.0    1.0  2019.0
#
#    Season_Fall  Season_Spring  Season_Summer  Season_Winter  Apple(Jholey)  \
# 0        False          False          False           True          False
# 1        False          False          False           True          False
# 2        False          False          False           True          False
# 3        False          False          False           True          False
# 4        False          False          False           True          False
#
#    Banana  Carrot(Local)  Cucumber(Local)  Garlic Dry Nepali  Lettuce  \
# ...

# %%
df1.drop('Commodity', axis = 1, inplace = True)

# %%
df1 = df1.dropna()

# %%
df1.replace([np.inf, -np.inf], np.nan, inplace=True)
df1 = df1.dropna()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df1)

# %%
x_train, x_test, y_train, y_test = train_test_split(df1.drop(['Average'], axis = 1),
 df1.Average, test_size = 0.1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_pred, y_test)
accuracy = model.score(x_test, y_test) * 100

print("MACHINE LEARNING MODEL'S MEAN SQUARE ERROR\t:\t", mse)
print("MACHINE LEARNING MODEL'S ACCURACY\t\t:\t", accuracy, '%')
# Out:
# MACHINE LEARNING MODEL'S MEAN SQUARE ERROR	:	 0.000423832703575877
# MACHINE LEARNING MODEL'S ACCURACY		:	 99.89298869239549 %
